# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
m = 100
X = 3 * np.random.randn(m, 1)
y = 0.5 * X**2 + X + 2 + np.random.randn(m, 1)

# %%
plt.plot(X, y, 'r.')
plt.axis([-3, 3, 0, 10])
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# %%
poly_features = PolynomialFeatures(degree=2, include_bias = False)# Tune the degree
X_poly = poly_features.fit_transform(X)
poly_regressor = LinearRegression()
poly_regressor.fit(X_poly, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
X_grid = np.arange(min(X),max(X),0.1)
X_grid = X_grid.reshape(len(X_grid),1)#Converts the list(1D) to 2D array
plt.plot(X, y, 'r.')
plt.plot(X_grid, poly_regressor.predict(poly_features.fit_transform(X_grid)), 'b-')
plt.axis([-3, 3, 0, 10])
plt.show()
